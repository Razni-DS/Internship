# %% [markdown]
# # Web Scraping Assignment 4

# %%
#importing necessary libraries
import selenium
import pandas as pd
import time
# Importing selenium webdriver
from selenium import webdriver

# Importing required Exceptions
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait
#Importing requests
import requests

# importing regex
import re

# %% [markdown]
# ### Q1- Scrape the details of most viewed videos on YouTube from Wikipedia.
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
# You need to find following details: A) Rank
# B) Name
# C) Artist
# D) Upload date E) Views

# %%
driver=webdriver.Chrome("/Users/sraazi_reni/Downloads/chromedriver 2")
#open a website
url = "https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos"
driver.get(url)
time.sleep(3)
# Out:
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_2388/2011959556.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome("/Users/sraazi_reni/Downloads/chromedriver 2")

# %%
#Creating empty list
Rank = []
Name = []
Artist = []
Upload_date = []
Views = []

#Scraping data of rank details
try:
    for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[1]")[:30]:
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append('-')
# Out:
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_2388/2424928880.py:10: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[1]")[:30]:

# %%
#Scraping data of video names
try:
    for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[2]")[:30]:
        Name.append(i.text)
except NoSuchElementException:
    Name.append('-')
# Out:
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_2388/1119555843.py:3: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[2]")[:30]:

# %%
#Scraping data of artist name
try:
    for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[3]")[:30]:
        Artist.append(i.text)
except NoSuchElementException:        
    Artist.append('-')
# Out:
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_2388/1679847225.py:3: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[3]")[:30]:

# %%
#Scraping data of upload date
try:
    for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[5]")[:30]:
        Upload_date.append(i.text)
except NoSuchElementException:        
    Upload_date.append('-')
# Out:
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_2388/4163564491.py:3: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[5]")[:30]:

# %%
#Scraping data of views
try:
    for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[4]")[:30]:
        Views.append(i.text)
except NoSuchElementException:
    Views.append('-')
# Out:
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_2388/3743936498.py:3: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[4]")[:30]:

# %%
#DATA FRAMEING
Youtube=pd.DataFrame({})
Youtube['Rank'] = Rank
Youtube['Name'] = Name
Youtube['Artist'] = Artist
Youtube['Uploaded Date'] = Upload_date
Youtube['Views'] = Views

# %%
#Printing data frame
Youtube
# Out:
#    Rank                                             Name  \
# 0    1.                            "Baby Shark Dance"[3]
# 1    2.                                   "Despacito"[6]
# 2    3.                       "Johny Johny Yes Papa"[12]
# 3    4.                               "Shape of You"[13]
# 4    5.                              "See You Again"[15]
# 5    6.                                  "Bath Song"[20]
# 6    7.                "Phonics Song with Two Words"[21]
# 7    8.                                "Uptown Funk"[22]
# 8    9.  "Learning Colors – Colorful Eggs on a Farm"[23]
# 9   10.   "Masha and the Bear – Recipe for Disaster"[24]
# 10  11.                              "Gangnam Style"[25]
# 11  12.                          "Wheels on the Bus"[30]
# 12  13.                             "Dame Tu Cosita"[31]
# 13  14.                                      "Sugar"[32]
# 14  15.                                       "Roar"[33]
# ...

# %%
driver.close()

# %% [markdown]
# ### Q2- Scrape the details team India’s international fixtures from bcci.tv. Url = https://www.bcci.tv/.
# You need to find following details:
# A) Match title (I.e. 1st ODI)
# B) Series
# C) Place
# D) Date
# E) Time
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
driver=webdriver.Chrome("/Users/sraazi_reni/Downloads/chromedriver")
#open a website
url='https://www.bcci.tv/'
driver.get(url)
time.sleep(3)
# Out:
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_812/1623365536.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome("/Users/sraazi_reni/Downloads/chromedriver")

# %%
#Creating empty list
Match_title = []
Series = []
Place = []
Date = []
Time = []

# %%
Int_button=driver.find_element_by_xpath('/html/body/nav/div/div[2]/ul[1]/li[2]/a')
Int_button.click()
# Out:
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_812/4273572358.py:1: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   Int_button=driver.find_element_by_xpath('/html/body/nav/div/div[2]/ul[1]/li[2]/a')

# %%
titles_tags=driver.find_elements_by_xpath("//span[@class='ng-binding']")
titles_tags[0:1]
# Out:
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_812/3886242235.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   titles_tags=driver.find_elements_by_xpath("//span[@class='ng-binding']")
# [<selenium.webdriver.remote.webelement.WebElement (session="744f51ca832ae06d54d744ac5e3ddf6c", element="e2826912-967d-4aaf-a9e9-4d2a41277a7a")>]

# %%
for i in titles_tags:
    title=i.text
    Match_title.append(title)
Match_title
# Out:
# ['SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022',
#  'SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022',
#  'SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022']

# %%
place_tags=driver.find_elements_by_xpath("//div[@class='fix-place ng-binding ng-scope']")
for i in place_tags:
    Place.append(i.text[10: ])
Place
# Out:
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_812/1478588955.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   place_tags=driver.find_elements_by_xpath("//div[@class='fix-place ng-binding ng-scope']")
# [' Dr YS Rajasekhara Reddy ACA-VDCA Cricket Stadium, Visakhapatnam',
#  ' Saurashtra Cricket Association Stadium, Rajkot',
#  ' M Chinnaswamy Stadium, Bengaluru']

# %%
series = driver.find_elements_by_xpath("//div[@class='fixture-card-mid d-flex align-items-center justify-content-between']")
for i in series:       
    if i.text is None :
        Series.append("--") 
    else:
        Series.append(i.text.replace("\n"," "))
# Out:
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_812/2068717203.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   series = driver.find_elements_by_xpath("//div[@class='fixture-card-mid d-flex align-items-center justify-content-between']")

# %%
Series
# Out:
# ['India vs South Africa', 'India vs South Africa', 'India vs South Africa']

# %%
for i in driver.find_elements_by_xpath("//div[@class='match-top-info d-flex align-items-center justify-content-between']"):
    Date.append(i.text[0:11])       
Date
# Out:
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_812/3121480614.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//div[@class='match-top-info d-flex align-items-center justify-content-between']"):
# ['14 JUN 2022', '17 JUN 2022', '19 JUN 2022']

# %%
for i in driver.find_elements_by_xpath("//div[@class='match-top-info d-flex align-items-center justify-content-between']"):
    Time.append(i.text[12: ])       
Time
# Out:
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_812/870035167.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//div[@class='match-top-info d-flex align-items-center justify-content-between']"):
# ['5:30 PM +04', '5:30 PM +04', '5:30 PM +04']

# %%
#data framing

BCCI=pd.DataFrame({})
BCCI['Match Title'] = Match_title
BCCI['Series'] = Series
BCCI['Place'] = Place
BCCI['Date'] = Date
BCCI['Time'] = Time
BCCI
# Out:
#                                   Match Title                 Series  \
# 0  SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022  India vs South Africa
# 1  SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022  India vs South Africa
# 2  SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022  India vs South Africa
#
#                                                Place         Date         Time
# 0   Dr YS Rajasekhara Reddy ACA-VDCA Cricket Stad...  14 JUN 2022  5:30 PM +04
# 1     Saurashtra Cricket Association Stadium, Rajkot  17 JUN 2022  5:30 PM +04
# 2                   M Chinnaswamy Stadium, Bengaluru  19 JUN 2022  5:30 PM +04

# %%
driver.close()

# %% [markdown]
# ### Q3- Scrape the details of selenium exception from guru99.com. Url = https://www.guru99.com/
# You need to find following details:
# A) Name
# B) Description
# Note: - From guru99 home page you have to reach to selenium exception handling page through code.

# %%
driver=webdriver.Chrome("/Users/sraazi_reni/Downloads/chromedriver")
#open a website
url='https://www.guru99.com/'
driver.get(url)
time.sleep(3)
# Out:
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_812/4032472600.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome("/Users/sraazi_reni/Downloads/chromedriver")

# %%
#Going to search bar and searching for selenium exception

ser_bar = driver.find_element_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/form/table/tbody/tr/td[1]/div/table/tbody/tr/td[1]/input")
ser_bar.send_keys("selenium exception handling")
ser_but = driver.find_element_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/form/table/tbody/tr/td[2]/button").click()
time.sleep(3)
# Out:
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_812/2989475008.py:3: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   ser_bar = driver.find_element_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/form/table/tbody/tr/td[1]/div/table/tbody/tr/td[1]/input")
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_812/2989475008.py:5: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   ser_but = driver.find_element_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/form/table/tbody/tr/td[2]/button").click()

# %%
urls = driver.find_element_by_xpath("//div[@class='gsc-expansionArea']//div//a")
page_url = urls.get_attribute("href")

driver.get(page_url)
time.sleep(5)

#Scraping data of names of exceptions
Name = []
for i in driver.find_elements_by_xpath("//table[@class='table table-striped']//tr//td[1]")[1:]:
    Name.append(i.text)
    
#Scraping data of descriptions of exceptions  
Description = []
for i in driver.find_elements_by_xpath("//table[@class='table table-striped']//tr//td[2]")[1:]:
    Description.append(i.text)
# Out:
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_812/4243381935.py:1: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   urls = driver.find_element_by_xpath("//div[@class='gsc-expansionArea']//div//a")
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_812/4243381935.py:9: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//table[@class='table table-striped']//tr//td[1]")[1:]:
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_812/4243381935.py:14: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//table[@class='table table-striped']//tr//td[2]")[1:]:

# %%
#data framing

Guru=pd.DataFrame({})
Guru['Name of Exception'] = Name
Guru['Description of Exception'] = Description
Guru
# Out:
#                       Name of Exception  \
# 0         ElementNotSelectableException
# 1                NoSuchElementException
# 2                  NoSuchFrameException
# 3               NoAlertPresentException
# 4                 NoSuchWindowException
# 5        StaleElementReferenceException
# 6              SessionNotFoundException
# 7                      TimeoutException
# 8                    WebDriverException
# 9             ConnectionClosedException
# 10     ElementClickInterceptedException
# 11      ElementNotInteractableException
# 12             ErrorInResponseException
# 13  ErrorHandler.UnknownServerException
# 14         ImeActivationFailedException
# 15             ImeNotAvailableException
# 16         InsecureCertificateException
# 17             InvalidArgumentException
# 18         InvalidCookieDomainException
# 19          InvalidCoordinatesException
# 20          InvalidElementStateExceptio
# 21            InvalidSessionIdException
# ...

# %%
driver.close()

# %% [markdown]
# ## Q4-Scrape the details of State-wise GDP of India from statisticstime.com. Url = http://statisticstimes.com/
# You have to find following details:
# A) Rank
# B) State
# C) GSDP(18-19)
# D) GSDP(17-18)
# E) Share(2017)
# F) GDP($ billion)
# Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
driver=webdriver.Chrome("/Users/sraazi_reni/Downloads/chromedriver")
#open a website
url='https://www.statisticstimes.com/'
driver.get(url)
time.sleep(3)
# Out:
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_812/848147346.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome("/Users/sraazi_reni/Downloads/chromedriver")

# %%
urls = driver.find_element_by_xpath("//div[@class='dropdown-content']//a[3]")
page = urls.get_attribute("href")
#Going to indian economy page
driver.get(page)  
time.sleep(5)
# Out:
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_812/3872698748.py:1: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   urls = driver.find_element_by_xpath("//div[@class='dropdown-content']//a[3]")

# %%
#get the url of page containing GDP of indian states
state_GDP = driver.find_element_by_xpath("//ul[@style='list-style-type:none;margin-left:20px;']/li/a")
GDP = state_GDP.get_attribute("href")

driver.get(GDP)
time.sleep(6)
# Out:
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_812/4231724697.py:2: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   state_GDP = driver.find_element_by_xpath("//ul[@style='list-style-type:none;margin-left:20px;']/li/a")

# %%
Rank=[]
State=[]
GSDP_19_20=[]
GSDP_18_19=[]
Share_18_19=[]
GDP_billion=[]

# %%
#Scraping data of rank
for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[1]"):
    Rank.append(i.text)

#Scraping state name
for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[2]"):
    State.append(i.text)

    
# Scraping GSDP at current price (19-20)
for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[3]"):
    GSDP_19_20.append(i.text)

    
#Scraping GSDP at current price (18-19)
for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[4]"):
    GSDP_18_19.append(i.text)

    
#Scraping Share(18-19)
for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[5]"):
    Share_18_19.append(i.text)

    
#Scraping GDP($ billion)
for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[6]"):
    GDP_billion.append(i.text)
# Out:
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_812/4110513708.py:2: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[1]"):
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_812/4110513708.py:6: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[2]"):
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_812/4110513708.py:11: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[3]"):
# ...

# %%
#DATA FRAMEING
Statistics=pd.DataFrame({})
Statistics['Rank'] = Rank
Statistics['State'] = State
Statistics['GSDP(19-20)'] = GSDP_19_20
Statistics['GSDP(18-19)'] = GSDP_18_19
Statistics['Share(18-19)'] = Share_18_19
Statistics['GDP($ billion)'] = GDP_billion

Statistics
# Out:
#    Rank                      State GSDP(19-20) GSDP(18-19) Share(18-19)  \
# 0     1                Maharashtra           -   2,632,792       13.94%
# 1     2                 Tamil Nadu   1,845,853   1,630,208        8.63%
# 2     3              Uttar Pradesh   1,687,818   1,584,764        8.39%
# 3     4                    Gujarat           -   1,502,899        7.96%
# 4     5                  Karnataka   1,631,977   1,493,127        7.91%
# 5     6                West Bengal   1,253,832   1,089,898        5.77%
# 6     7                  Rajasthan   1,020,989     942,586        4.99%
# 7     8             Andhra Pradesh     972,782     862,957        4.57%
# 8     9                  Telangana     969,604     861,031        4.56%
# 9    10             Madhya Pradesh     906,672     809,592        4.29%
# 10   11                     Kerala           -     781,653        4.14%
# 11   12                      Delhi     856,112     774,870        4.10%
# ...

# %%
driver.close()

# %% [markdown]
# ### Q5-Scrape the details of trending repositories on Github.com. Url = https://github.com/
# You have to find the following details:
# A) Repository title
# B) Repository description C) Contributors count
# D) Language used
# Note: - From the home page you have to click on the trending option from Explore menu through code.

# %%
driver=webdriver.Chrome("/Users/sraazi_reni/Downloads/chromedriver")
#open a website
url='https://github.com/'
driver.get(url)
time.sleep(3)
# Out:
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_812/1480056307.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome("/Users/sraazi_reni/Downloads/chromedriver")

# %%
#Getting explore button and clicking on it
explore = driver.find_element_by_xpath("/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details").click()

#Selecting trending option
trend_url = driver.find_element_by_xpath("/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul/li[5]/a")
urls = trend_url.get_attribute("href")
driver.get(urls)
# Out:
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_812/3472573901.py:2: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   explore = driver.find_element_by_xpath("/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details").click()
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_812/3472573901.py:5: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   trend_url = driver.find_element_by_xpath("/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul/li[5]/a")

# %%
#Creating empty list for scraping into it

repository = []
url = []
Description = []
Contributors = []
Language = []
lang = []

# %%
#Fetching urls for each repository
repos = driver.find_elements_by_xpath("//h1[@class = 'h3 lh-condensed']//a")
for i in repos:
    url.append(i.get_attribute("href"))

    
#Scraping data of repository title
title = driver.find_elements_by_xpath("//h1[@class = 'h3 lh-condensed']")
for i in title:
    repository.append(i.text)

    
#Scraping data from every repository page
for i in url:
    driver.get(i)
    time.sleep(3)
    
    
    #Scraping data of decription
    try:
        desc = driver.find_element_by_xpath("//p[@class='f4 my-3']")
        Description.append(desc.text)
    except NoSuchElementException:
        Description.append('-')
        
        
    #Scraping data of contributors
    try:
        cont_tags = driver.find_element_by_xpath("//*[contains(text(),'    Contributors ')]")
        Contributors.append(cont_tags.text.replace('Contributors',''))
    except NoSuchElementException:
        Contributors.append('-')
        
        
     #fetching Languages used
    try:
        for i in driver.find_elements_by_xpath("//span[@class='color-text-primary text-bold mr-1']"):
            lang.append(i.text)
        Language.append(lang)
    except NoSuchElementException:
        Language.append('-')
# Out:
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_812/292172632.py:2: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   repos = driver.find_elements_by_xpath("//h1[@class = 'h3 lh-condensed']//a")
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_812/292172632.py:8: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   title = driver.find_elements_by_xpath("//h1[@class = 'h3 lh-condensed']")
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_812/292172632.py:21: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   desc = driver.find_element_by_xpath("//p[@class='f4 my-3']")
# ...

# %%
print(len(repository),len(Description),len(Language),len(Contributors))
# Out:
# 25 25 25 25

# %%
#Data framing

Github=pd.DataFrame({})
Github['Repository title'] = repository
Github['Repository description'] = Description
Github['Contributors count'] = Contributors
Github['Language used'] = Language

Github
# Out:
#                             Repository title  \
# 0              digitalocean / nginxconfig.io
# 1                      home-assistant / core
# 2                    borisdayma / dalle-mini
# 3                freeCodeCamp / freeCodeCamp
# 4                     TheAlgorithms / Python
# 5                            sheepla / pingu
# 6         adrianhajdin / project_fitness_app
# 7                            iptv-org / iptv
# 8                    ossu / computer-science
# 9                TBD54566975 / collaboration
# 10                         medusajs / medusa
# 11                     skyline-emu / skyline
# 12               saharmor / dalle-playground
# 13                          knadh / dns.toys
# 14                       vaxerski / Hyprland
# 15    microsoft / Data-Science-For-Beginners
# 16  EbookFoundation / free-programming-books
# 17                               atom / atom
# 18   awesome-selfhosted / awesome-selfhosted
# 19               sherlock-project / sherlock
# ...

# %%
driver.close()

# %% [markdown]
# ### Q6-Scrape the details of top 100 songs on billiboard.com. Url = https:/www.billboard.com/
# You have to find the following details:
# A) Song name
# B) Artist name
# C) Last week rank
# D) Peak rank
# E) Weeks on board
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
driver=webdriver.Chrome("/Users/sraazi_reni/Downloads/chromedriver")
#open a website
url='https://www.billboard.com/'
driver.get(url)
time.sleep(3)
# Out:
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_812/2487809580.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome("/Users/sraazi_reni/Downloads/chromedriver")

# %%
#Clicking on charts

charts=driver.find_element_by_xpath("/html/body/div[3]/header/div[1]/div/div/div[2]/div/nav/ul/li[1]/a").click()
# Out:
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_812/1568030346.py:3: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   charts=driver.find_element_by_xpath("/html/body/div[3]/header/div[1]/div/div/div[2]/div/nav/ul/li[1]/a").click()

# %%
# clicking the hot 100
hot100=driver.find_element_by_xpath("/html/body/div[3]/main/div[2]/div[1]/div[1]/div/div/div[1]/div[1]/div[2]/span/a")
hot100.click()
# Out:
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_812/1137608878.py:2: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   hot100=driver.find_element_by_xpath("/html/body/div[3]/main/div[2]/div[1]/div[1]/div/div/div[1]/div[1]/div[2]/span/a")

# %%
#creating empty list for scraping data
Song_name=[]
Artist_name=[]
Last_week_rank=[]
Peak_rank=[]
Weeks_on_board=[]

# scraping Song name
song = driver.find_elements_by_xpath("//ul[@class='lrv-a-unstyle-list lrv-u-flex lrv-u-height-100p lrv-u-flex-direction-column@mobile-max']")
for i in song:       
    Song_name.append(i.text.split('\n')[0])
    Artist_name.append(i.text.split('\n')[1])
# Out:
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_812/2620525276.py:9: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   song = driver.find_elements_by_xpath("//ul[@class='lrv-a-unstyle-list lrv-u-flex lrv-u-height-100p lrv-u-flex-direction-column@mobile-max']")

# %%
for i in song:
    Last_week_rank.append(i.text.split('\n')[2])
    Peak_rank.append(i.text.split('\n')[3])
    Weeks_on_board.append(i.text.split('\n')[4])

# %%
print(len(Last_week_rank),len(Peak_rank),len(Weeks_on_board))
# Out:
# 100 100 100

# %%
Billboard = pd.DataFrame({'Song Name': Song_name,
                         'Artist Name': Artist_name,
                         'Last week rank': Last_week_rank,
                         'Peak rank': Peak_rank,
                         'Weeks on board': Weeks_on_board})
Billboard
# Out:
#             Song Name                    Artist Name Last week rank Peak rank  \
# 0           As It Was                   Harry Styles              1         1
# 1         First Class                    Jack Harlow              2         1
# 2          Wait For U  Future Featuring Drake & Tems              3         1
# 3     About Damn Time                          Lizzo              5         4
# 4          Heat Waves                  Glass Animals              6         1
# ..                ...                            ...            ...       ...
# 95    Love You Better                         Future             84        12
# 96        Wild Hearts                    Keith Urban              -        97
# 97  Last Night Lonely                      Jon Pardi              -        98
# 98           7500 OBO                     Tim McGraw              -        99
# 99  Until I Found You                Stephen Sanchez              -       100
#
#    Weeks on board
# ...

# %%
driver.close()

# %% [markdown]
# ### Q7-Scrape the details of Data science recruiters from naukri.com. Url = https://www.naukri.com/
# You have to find the following details:
# A) Name
# B) Designation
# C) Company
# D) Skills they hire for
# E) Location
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and click on search. All this should be done through code

# %%
driver=webdriver.Chrome("/Users/sraazi_reni/Downloads/chromedriver")
#open a website
url='https://www.naukri.com/hr-recruiters-consultants'
driver.get(url)
time.sleep(3)
# Out:
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_803/1605854524.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome("/Users/sraazi_reni/Downloads/chromedriver")

# %% [markdown]
# ### the updated naukri.com website does not have recruiters tab on the home page. so directly used recruiters website.

# %%
#accesing search bar
search=driver.find_element_by_xpath("//input[@class='sugInp']")
search.send_keys("Data Science")
# Out:
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_803/3272183867.py:2: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   search=driver.find_element_by_xpath("//input[@class='sugInp']")

# %%
#clicking on search button
button=driver.find_element_by_xpath("//button[@id='qsbFormBtn']")
button.click()
# Out:
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_803/3512291310.py:2: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   button=driver.find_element_by_xpath("//button[@id='qsbFormBtn']")

# %%
#scrapping names

Name=[]
try:
    names=driver.find_elements_by_xpath("//div[@class='recInfo']/div/p/a[1]")
    for i in names:
        Name.append(i.text)
except NoSuchElementException:           
    Name.append('No details')

time.sleep(2)
# Out:
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_803/2876290290.py:5: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   names=driver.find_elements_by_xpath("//div[@class='recInfo']/div/p/a[1]")

# %%
#scrapping designation
Designation=[]
try:
    designation_list=driver.find_elements_by_xpath("//div[@class='recInfo']/div/p/span[1]")
    for i in designation_list:
        Designation.append(i.text)
except NoSuchElementException:        
    Designation.append('No details')
    
time.sleep(2)
# Out:
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_803/2488204211.py:4: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   designation_list=driver.find_elements_by_xpath("//div[@class='recInfo']/div/p/span[1]")

# %%
#scrapping company names
Company=[]
try:
    companies=driver.find_elements_by_xpath("//div[@class='recInfo']/div/p/a[2]")
    for i in companies:
        Company.append(i.text)
except NoSuchElementException:
    Company.append('No details')

time.sleep(2)
# Out:
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_803/4171030941.py:4: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   companies=driver.find_elements_by_xpath("//div[@class='recInfo']/div/p/a[2]")

# %%
#scrapping location names
Location=[]
try:
    loc=driver.find_elements_by_xpath("//div[@class='recInfo']/div/p/span[2]")
    for i in loc:   
        Location.append(i.text)
except NoSuchElementException:
    Location.append("No details")       
time.sleep(2)
# Out:
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_803/770124772.py:4: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   loc=driver.find_elements_by_xpath("//div[@class='recInfo']/div/p/span[2]")

# %%
Skill=[]
try:
    skills=driver.find_elements_by_xpath("//div[@class='recInfo']/div[2]")
    for i in skills:
        Skill.append(i.text)
except NoSuchElementException:
    Skill.append('No details')   
time.sleep(2)
# Out:
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_803/943637952.py:3: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   skills=driver.find_elements_by_xpath("//div[@class='recInfo']/div[2]")

# %%
#creating dataframe
DS_Recruiters=pd.DataFrame({'Name':Name,
                'Designation':Designation,
                'Company':Company,
                "Location":Location,
                'Hire_for_Skillset':Skill})
DS_Recruiters
# Out:
#                             Name                        Designation  \
# 0                 Santhosh Kumar  Associate Manager Human Resources
# 1                   Gauri Bhosle                    Human Resources
# 2                     Surendra R                  Company Recruiter
# 3                    Neha Pandey                  Company Recruiter
# 4                    Vinita Raut                  Company Recruiter
# 5            BALA Sakthivelmuthu                  Company Recruiter
# 6                Anandi Bandekar         Deputy Manager Recruitment
# 7                          Cameo                  Company Recruiter
# 8                          Cameo                  Company Recruiter
# 9           Shirish Anand Koshti                  Company Recruiter
# 10                   Charu Saini                  Company Recruiter
# 11                  Prerna Mohan                  Company Recruiter
# 12                Pralhad DHUMAL                  Company Recruiter
# ...

# %%
driver.close()

# %% [markdown]
# ### 8. Scrape the details of Highest selling novels.
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey- compare/
# You have to find the following details:
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre

# %%
driver=webdriver.Chrome("/Users/sraazi_reni/Downloads/chromedriver")
#open a website
url='https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare'
driver.get(url)
time.sleep(3)
# Out:
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_803/2940679144.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome("/Users/sraazi_reni/Downloads/chromedriver")

# %%
#scrapping book names
Book=[]
try:
    names=driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[2]')
    for i in names:
        Book.append(i.text)
except NoSuchElementException:              
    Book.append('No details')
time.sleep(2)

#scrapping author names
Author=[]
try:
    names=driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[3]")
    for i in names:
        Author.append(i.text)
except NoSuchElementException:
    Author.append('No details')
time.sleep(2)

#scrapping Sales
Sale=[]
try:
    sale=driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[4]")
    for i in sale:
        Sale.append(i.text)
except NoSuchElementException:
    Sale.append('No details')
time.sleep(2)    

#scrapping publisher
Publisher=[]
try:
    publishers=driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[5]")
    for i in publishers:
        Publisher.append(i.text)
except NoSuchElementException:#handling no such element exception
    Publisher.append('No details')
time.sleep(2)

#scraping genre
Genre=[]
try:
    genres=driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[6]")
    for i in genres:
        Genre.append(i.text)
except NoSuchElementException:#handling no such element exception
    Genre.append('No details')
time.sleep(2)
# Out:
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_803/2599796389.py:4: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   names=driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[2]')
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_803/2599796389.py:14: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   names=driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[3]")
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_803/2599796389.py:24: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   sale=driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[4]")
# ...

# %%
print(len(Book),len(Author),len(Sale),len(Publisher),len(Genre))
# Out:
# 100 100 100 100 100

# %%
#creating dataframe
TopBooks=pd.DataFrame({"Book_name":Book,
                "Author_name":Author,
                'Volume sold':Sale,
                'Publisher':Publisher,
                'Genre':Genre})
TopBooks
# Out:
#                                             Book_name       Author_name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volume sold        Publisher                        Genre
# ...

# %%
driver.close()

# %% [markdown]
# ### 9. Scrape the details most watched tv series of all time from imdb.com. Url = https://www.imdb.com/list/ls095964455/
# You have to find the following details: A) Name
# B) Year span
# C) Genre
# D) Run time E) Ratings F) Votes

# %%
driver=webdriver.Chrome("/Users/sraazi_reni/Downloads/chromedriver")
#open a website
url='https://www.imdb.com/list/ls095964455/'
driver.get(url)
time.sleep(3)
# Out:
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_803/1322115350.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome("/Users/sraazi_reni/Downloads/chromedriver")

# %%
# scraping name of webseries
Name=[]
try:
    names=driver.find_elements_by_xpath("//h3[@class='lister-item-header']/a")
    for i in names:
        Name.append(i.text)
except NosuchElementException:
    Name.append('No details')
    
time.sleep(2)


# scraping year of release
Year=[]
try:
    release=driver.find_elements_by_xpath("//h3[@class='lister-item-header']/span[2]")
    for i in release:
        Year.append(i.text)
except NosuchElementException:
    Year.append('No details')

time.sleep(2)


# scraping genre
Genre=[]
try:
    genres=driver.find_elements_by_xpath("//span[@class='genre']")
    for i in genres:
        Genre.append(i.text)
except NoSuchElementException:
    Genre.append('No details')

time.sleep(2)

# scraping run_time
run_time=[]
try:
    rt=driver.find_elements_by_xpath("//span[@class='runtime']")
    for i in rt:
        run_time.append(i.text)
except NoSuchElementException:
    run_time.append('No details') 
time.sleep(2)


# scraping rating
Ratings=[]
try:
    rate=driver.find_elements_by_xpath("//div[@class='ipl-rating-star small']/span[2]")
    for i in rate:
        Ratings.append(i.text)
except NoSuchElementException:
    Ratings.append('No details')

time.sleep(2)

# scraping votes
Votes=[]
try:
    vt=driver.find_elements_by_xpath("//span[@name='nv']")
    for i in vt:
        Votes.append(i.text)
except NoSuchElementException:
    Votes.append('No details')

time.sleep(2)
# Out:
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_803/3028935043.py:4: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   names=driver.find_elements_by_xpath("//h3[@class='lister-item-header']/a")
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_803/3028935043.py:16: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   release=driver.find_elements_by_xpath("//h3[@class='lister-item-header']/span[2]")
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_803/3028935043.py:28: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   genres=driver.find_elements_by_xpath("//span[@class='genre']")
# ...

# %%
print(len(Name),len(Year),len(run_time),len(Votes),len(Genre),len(Ratings))
# Out:
# 100 100 100 100 100 100

# %%
#dataframe
Most_Watched_TV=pd.DataFrame({"Name":Name,
                "Year_span":Year,
                "Genre":Genre,
                "Run_time":run_time,
                "Ratings":Ratings,
                "Votes":Votes})
Most_Watched_TV
# Out:
#                               Name    Year_span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run_time Ratings      Votes
# 0    57 min     9.2  1,995,240
# ...

# %%
driver.close()

# %% [markdown]
# ### 10. Details of Datasets from UCI machine learning repositories. Url = https://archive.ics.uci.edu/
# You have to find the following details:
# A) Dataset name B) Data type
# C) Task
# D) Attribute type E) No of instances F) No of attribute G) Year
# Note: - from the home page you have to go to the ShowAllDataset page through code.

# %%
driver=webdriver.Chrome("/Users/sraazi_reni/Downloads/chromedriver")
#open a website
url='https://archive.ics.uci.edu/'
driver.get(url)
time.sleep(3)
# Out:
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_803/4136679761.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome("/Users/sraazi_reni/Downloads/chromedriver")

# %%
#view all datasets link

ds=driver.find_element_by_xpath("//a[@href='datasets.php']")
ds.click()
time.sleep(1)
# Out:
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_803/2134609939.py:3: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   ds=driver.find_element_by_xpath("//a[@href='datasets.php']")

# %%
#scroll
for _ in range(1000):
    driver.execute_script("window.scrollBy(0,10000)")
time.sleep(2)

# %%
# creating variables to store the data
Name = []
Data_type = []
Task = []
Attribute = []
Instance = []
No_of_attribute = []
Year = []

#scraping the dataset name
for n in driver.find_elements_by_xpath('/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[1]'):
    Name.append(i.text)
    
#scraping the data type
for d in driver.find_elements_by_xpath('/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]'):
    Data_type.append(j.text)
    
#scraping the task
for t in driver.find_elements_by_xpath('/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[3]'):
    Task.append(k.text)
    
#scraping the attribute type
for a in driver.find_elements_by_xpath('/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[4]'):
    Attribute.append(l.text)
    
#scraping the number of instance
for i in driver.find_elements_by_xpath('/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[5]'):
    Instance.append(m.text)
    
#scraping the number of attribute
for o in driver.find_elements_by_xpath('/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[6]'):
    No_of_attribute.append(n.text)
    
#scraping the year
for y in driver.find_elements_by_xpath('/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[7]'):
    Year.append(o.text)
# Out:
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_803/826914083.py:11: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath('/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[1]'):
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_803/826914083.py:15: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for j in driver.find_elements_by_xpath('/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]'):
# /var/folders/kv/5_zby7sj1d1drptxz1qp_z9h0000gn/T/ipykernel_803/826914083.py:19: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for k in driver.find_elements_by_xpath('/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[3]'):
# ...

# %%
print(len(Name),len(Data_type),len(No_of_attribute),len(Attribute),len(Instance),len(Year),len(Task))
# Out:
# 623 623 623 623 623 623 623

# %%
#creating the dataframe
Datasets = pd.DataFrame({'Dataset Name': Name,'Data Type': Data_type,'Task': Task,'Attribute Type': Attribute,
                        'Number of Instance': Instance,'Number of Attribute': No_of_attribute,'Year': Year})
Datasets
# Out:
#                                           Dataset Name  \
# 0                                                 Name
# 1                                              Abalone
# 2                                                Adult
# 3                                            Annealing
# 4                         Anonymous Microsoft Web Data
# ..                                                 ...
# 618    Influenza outbreak event prediction via Twit...
# 619                      Turkish Music Emotion Dataset
# 620                      Maternal Health Risk Data Set
# 621                          Room Occupancy Estimation
# 622    Image Recognition Task Execution Times in Mo...
#
#                       Data Type                  Task  \
# 0                    Data Types          Default Task
# 1                 Multivariate        Classification
# 2                 Multivariate        Classification
# 3                 Multivariate        Classification
# ...

# %% [markdown]
# ## Finished
